# %%
import norse
import torch

# %% [markdown]
# # Creating a model

# %%
model = norse.torch.SequentialState(
    norse.torch.LIFBoxCell(),
    torch.nn.Conv2d(2, 8, 3),
    torch.nn.MaxPool2d(2),
    norse.torch.LIFBoxCell(),
    torch.nn.Conv2d(8, 16, 3),
    torch.nn.MaxPool2d(2),
    torch.nn.Flatten(1),
    torch.nn.Linear(784, 10)
)

# %%
model(torch.empty(1, 2, 34, 34))[0].shape
# Out:
# torch.Size([1, 10])

# %%
nir_graph = norse.torch.to_nir(model, torch.empty(1, 2, 34, 34))

# %%
nir_graph.nodes.keys()
# Out:
# dict_keys(['input', '0', '1', '2', '3', '4', '5', '6', '7', 'output'])

# %%
nir_graph.edges
# Out:
# [('7', 'output'),
#  ('0', '1'),
#  ('2', '3'),
#  ('1', '2'),
#  ('4', '5'),
#  ('6', '7'),
#  ('3', '4'),
#  ('input', '0'),
#  ('5', '6')]

# %% [markdown]
# # Training

# %%
import tqdm
import tonic

# %%
to_frame = tonic.transforms.ToFrame(sensor_size=tonic.datasets.NMNIST.sensor_size, time_window = 1e3)
dataset = tonic.datasets.NMNIST(".", transform=to_frame, train=False)
loader = torch.utils.data.DataLoader(dataset, shuffle=True, batch_size=10, collate_fn=tonic.collation.PadTensors(batch_first=False))

# %%
dataset[0][0].shape
# Out:
# (308, 2, 34, 34)

# %%
optimizer = torch.optim.Adam(model.parameters())
model = model.cuda()
correct = 0
for (x, label) in tqdm.tqdm(loader):
    optimizer.zero_grad()
    state = None
    out = []
    for timestep in x:
        y, state = model(timestep.cuda(), state)
        out.append(y)
    out = torch.stack(out).mean(0)
    pred = out.argmax(0)
    correct += out.argmax(0, keepdim=True).eq(label.cuda().view_as(pred)).sum()
    loss = torch.nn.functional.cross_entropy(out, label.cuda())
    loss.backward()
    optimizer.step()
    
print(f"Correct: {100 * correct / len(dataset):.1f}%")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [05:42<00:00,  2.92it/s]
# Correct: 9.8%

# %% [markdown]
# # Export to NIR

# %%
norse.torch.to_nir(model.cpu(), torch.empty(1, 2, 34, 34))
# Out:
# NIRGraph(nodes={'input': Input(input_type={'input': array([ 1,  2, 34, 34])}), '0': LIF(tau=tensor(1.0000e-05), r=tensor(1.), v_leak=tensor(0.), v_threshold=tensor(1.)), '1': Conv2d(input_shape=None, weight=tensor([[[[ 0.2302, -0.1923,  0.1116],
#           [ 0.0519,  0.1096, -0.1946],
#           [-0.1547, -0.2132,  0.0488]],
#
#          [[ 0.1668,  0.2272, -0.1020],
#           [ 0.0744,  0.1548, -0.1317],
#           [ 0.1251, -0.1976, -0.0381]]],
#
#
#         [[[-0.1518,  0.2230, -0.0752],
#           [-0.1672, -0.1807,  0.0759],
#           [-0.2206,  0.1103,  0.0126]],
#
#          [[ 0.1893,  0.0253,  0.1672],
#           [ 0.1789,  0.1015,  0.2072],
#           [ 0.1583, -0.0384, -0.0347]]],
#
#
#         [[[ 0.1673, -0.0356, -0.0323],
#           [ 0.2265,  0.2239, -0.2084],
#           [-0.1985,  0.0692,  0.0279]],
#
#          [[ 0.0436, -0.1635, -0.0721],
#           [-0.0762, -0.2009, -0.0613],
#           [-0.0784, -0.0248,  0.1876]]],
#
#
#         [[[-0.1281, -0.2353, -0.2279],
#           [ 0.0162,  0.0070, -0.0138],
#           [-0.1663,  0.0718, -0.1462]],
#
#          [[-0.1625,  0.1236, -0.0667],
#           [ 0.1236, -0.1738, -0.0335],
#           [ 0.1562, -0.1898,  0.0014]]],
#
#
#         [[[-0.1208,  0.0180,  0.1295],
#           [-0.1628,  0.2022,  0.0313],
#           [-0.0844, -0.0766, -0.0401]],
#
#          [[ 0.1851,  0.0031, -0.0082],
#           [-0.0050, -0.2341,  0.0281],
#           [-0.0622,  0.1802,  0.0081]]],
#
#
#         [[[ 0.1164,  0.0761, -0.1704],
#           [ 0.0009, -0.0342,  0.1262],
#           [ 0.1244, -0.0052, -0.1957]],
#
#          [[ 0.0393,  0.1701,  0.1526],
#           [-0.1326,  0.2192,  0.0390],
#           [ 0.1708,  0.0807, -0.1553]]],
#
#
#         [[[-0.2032, -0.1236, -0.1266],
#           [ 0.0358,  0.0710, -0.0515],
#           [-0.1813, -0.0650,  0.0278]],
#
#          [[-0.0868, -0.1545, -0.1484],
#           [-0.1104, -0.0306,  0.2288],
#           [ 0.1984,  0.0825, -0.0062]]],
#
#
#         [[[ 0.0772,  0.1448,  0.0485],
#           [-0.0236, -0.2147, -0.0995],
#           [-0.1087, -0.0344, -0.1871]],
#
#          [[ 0.0400, -0.1952,  0.0772],
#           [ 0.2276,  0.1527,  0.0600],
#           [ 0.2327,  0.1868, -0.1395]]]]), stride=(1, 1), padding=(0, 0), dilation=(1, 1), groups=1, bias=tensor([-0.0735,  0.1596,  0.1006, -0.1316,  0.0990, -0.1681,  0.0298,  0.2802])), '2': None, '3': LIF(tau=tensor(1.0000e-05), r=tensor(1.), v_leak=tensor(0.), v_threshold=tensor(1.)), '4': Conv2d(input_shape=None, weight=tensor([[[[-0.0855, -0.0585, -0.0514],
#           [ 0.0618,  0.0898,  0.0679],
#           [-0.0063,  0.0528, -0.0660]],
#
#          [[-0.1089, -0.0412, -0.0687],
#           [ 0.0693, -0.1120,  0.0236],
#           [ 0.0966, -0.1012,  0.0757]],
#
#          [[ 0.0763, -0.1143, -0.0514],
#           [-0.0910,  0.0352,  0.0524],
#           [ 0.0103, -0.0870,  0.0389]],
#
#          ...,
#
#          [[-0.0717, -0.0339, -0.0484],
#           [-0.1020, -0.0439, -0.0927],
#           [ 0.0291,  0.0553,  0.0067]],
#
#          [[ 0.0884, -0.0935,  0.0310],
#           [ 0.0995, -0.0659, -0.1163],
#           [ 0.0085,  0.0104, -0.0817]],
#
#          [[ 0.0458, -0.0551,  0.0110],
#           [-0.0089, -0.0417, -0.0412],
#           [-0.0511,  0.1078,  0.0323]]],
#
#
#         [[[ 0.0576, -0.0357, -0.0924],
#           [ 0.1072,  0.0152, -0.0832],
#           [ 0.1138,  0.0994,  0.1001]],
#
#          [[-0.0743, -0.1129, -0.0841],
#           [-0.0035, -0.0941, -0.0666],
#           [ 0.0105, -0.0235, -0.1142]],
#
#          [[-0.0814, -0.0827,  0.1065],
#           [ 0.0674,  0.1138,  0.0040],
#           [-0.0120,  0.0993,  0.0948]],
#
#          ...,
#
#          [[ 0.0819,  0.0603, -0.0578],
#           [-0.0787, -0.0439,  0.0177],
#           [-0.0814, -0.1047, -0.1063]],
#
#          [[ 0.0710, -0.0683, -0.0236],
#           [-0.1089,  0.0706,  0.0958],
#           [-0.0331, -0.1044,  0.1118]],
#
#          [[ 0.0429,  0.0994, -0.0383],
#           [ 0.1063, -0.0692,  0.0638],
#           [-0.0781,  0.0939, -0.0407]]],
#
#
#         [[[-0.0182, -0.0416, -0.0332],
#           [ 0.0885,  0.1039,  0.0350],
#           [ 0.0270,  0.0661, -0.0038]],
#
#          [[ 0.0615, -0.0464,  0.0128],
#           [ 0.0550, -0.0154, -0.1061],
#           [ 0.1125, -0.0169, -0.1123]],
#
#          [[-0.0617,  0.0832,  0.0463],
#           [-0.0767, -0.0346,  0.0764],
#           [ 0.0371, -0.0752,  0.0435]],
#
#          ...,
#
#          [[ 0.0157,  0.0382, -0.1172],
#           [ 0.0841,  0.0920,  0.0773],
#           [ 0.1093,  0.0950, -0.1123]],
#
#          [[-0.0503, -0.0546,  0.0690],
#           [ 0.1139, -0.0123,  0.0094],
#           [ 0.0284,  0.0365,  0.0703]],
#
#          [[-0.0659, -0.0183, -0.0706],
#           [-0.0006, -0.0005, -0.0890],
#           [-0.0739, -0.0114,  0.0796]]],
#
#
#         ...,
#
#
#         [[[-0.0194, -0.0037, -0.0366],
#           [ 0.0984,  0.0633,  0.0515],
#           [ 0.0100,  0.0468, -0.0616]],
#
#          [[ 0.1108, -0.0206,  0.0641],
#           [ 0.0060,  0.0478, -0.0108],
#           [ 0.0747,  0.0321, -0.1145]],
#
#          [[ 0.0491, -0.0656,  0.0202],
#           [-0.0319,  0.0283,  0.0519],
#           [ 0.0535,  0.0779, -0.1065]],
#
#          ...,
#
#          [[ 0.0073,  0.0365, -0.0236],
#           [-0.0445,  0.0651,  0.1003],
#           [ 0.0348, -0.0791, -0.0593]],
#
#          [[-0.0632, -0.0065,  0.1103],
#           [ 0.1125, -0.0698,  0.0538],
#           [ 0.0210,  0.0499, -0.0297]],
#
#          [[ 0.1060,  0.1054,  0.0710],
#           [-0.0398,  0.0352, -0.0353],
#           [-0.0358, -0.0409, -0.0533]]],
#
#
#         [[[ 0.0719, -0.1174, -0.0733],
#           [ 0.0488, -0.0039,  0.0587],
#           [-0.0330, -0.0377, -0.0127]],
#
#          [[-0.0873,  0.0809, -0.0251],
#           [-0.0379,  0.1013,  0.0053],
#           [-0.0900, -0.0445, -0.0254]],
#
#          [[ 0.0420, -0.0450, -0.0951],
#           [-0.0459,  0.0396,  0.0477],
#           [-0.0290, -0.0646, -0.0016]],
#
#          ...,
#
#          [[ 0.0267,  0.0408, -0.0981],
#           [-0.1037, -0.0791,  0.0891],
#           [-0.0439,  0.0412, -0.1105]],
#
#          [[-0.0382,  0.0816, -0.0818],
#           [-0.0281, -0.0300,  0.0416],
#           [-0.0843, -0.0759,  0.1137]],
#
#          [[ 0.1110,  0.0503,  0.0948],
#           [-0.0581,  0.0874,  0.0487],
#           [ 0.0376,  0.1043, -0.0936]]],
#
#
#         [[[ 0.0107,  0.0791,  0.0048],
#           [ 0.0486,  0.0797,  0.0434],
#           [-0.0549, -0.0474, -0.0392]],
#
#          [[ 0.1045,  0.0832,  0.0544],
#           [ 0.0919, -0.0223, -0.0524],
#           [-0.0374, -0.0516,  0.0076]],
#
#          [[-0.0892, -0.0905,  0.0016],
#           [ 0.0201, -0.0385,  0.0531],
#           [-0.0833, -0.1145,  0.0883]],
#
#          ...,
#
#          [[ 0.0372,  0.0765, -0.0179],
#           [-0.0957, -0.0733, -0.0044],
#           [ 0.0897,  0.0236, -0.0333]],
#
#          [[ 0.1042, -0.0900,  0.0396],
#           [-0.0052,  0.0962, -0.0508],
#           [-0.0543,  0.0931,  0.0592]],
#
#          [[ 0.1174, -0.0381,  0.0204],
#           [-0.0885,  0.0282,  0.0677],
#           [ 0.0839, -0.0381,  0.0565]]]]), stride=(1, 1), padding=(0, 0), dilation=(1, 1), groups=1, bias=tensor([ 0.0038,  0.0130,  0.0061, -0.0074,  0.0023, -0.0148,  0.0310, -0.0128,
#         -0.0085,  0.0096, -0.0067,  0.0059,  0.0087, -0.0186, -0.0030,  0.0014])), '5': None, '6': None, '7': Affine(weight=tensor([[ 0.0314, -0.0180,  0.0010,  ..., -0.0300, -0.0043,  0.0302],
#         [ 0.0169, -0.0253,  0.0040,  ...,  0.0078, -0.0133,  0.0087],
#         [-0.0293,  0.0291,  0.0204,  ...,  0.0169,  0.0421,  0.0226],
#         ...,
#         [-0.0012,  0.0281,  0.0295,  ...,  0.0017, -0.0353,  0.0285],
#         [-0.0371,  0.0012, -0.0092,  ..., -0.0035,  0.0035, -0.0406],
#         [-0.0010, -0.0270,  0.0178,  ...,  0.0073, -0.0578, -0.0115]]), bias=tensor([-0.0011,  0.0743,  0.0031,  0.0280,  0.0112, -0.0352, -0.0308,  0.0196,
#          0.0090,  0.0182])), 'output': Output(output_type={'output': array([ 1, 10])})}, edges=[('7', 'output'), ('0', '1'), ('2', '3'), ('1', '2'), ('4', '5'), ('6', '7'), ('3', '4'), ('input', '0'), ('5', '6')])
